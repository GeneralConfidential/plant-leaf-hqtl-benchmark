# %% [markdown]
# # S2 multi-seed evaluation (10 tomato, 10 qubits)
#
# Prefer the script for full runs:
#
# ```bash
# uv run python paper-release/code/run_s2_seeds.py --rebuild-splits
# uv run python paper-release/code/run_s2_seeds.py --models hybrid --skip-existing
# ```
#
# Outputs: `results/elevation/s2a_runs.csv`, `s2a_summary.csv`
